# %%
import pandas as pd
import sys
import random
import json
from jinja2 import Environment, FileSystemLoader
from dotenv import load_dotenv
import os
import litellm

# %%
MODEL = "gpt-4o"
LANGUAGE = "en" # Change to "tr" or "ar" for Turkish or Arabic

# %%
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
tenv = Environment(loader=FileSystemLoader('templates'))

# %%
q_temp = tenv.get_template(f'ask-question-{LANGUAGE}.txt')

# %%
df = pd.read_csv(f'data/batik-v1-{LANGUAGE}.csv')
cache  = {}

# %%
q_temp.render(question="")
# Out:
# 'Aşağıdaki soruya en iyi cevabı seçin:\n\n\n\nseçenekler listesinden (her satırda bir seçenek)\n\n\n\nCevabınızı json formatında, tek bir alanla "answer" olarak çıkartın \nve yukarıdaki sorunun cevabını belirtin.'

# %%
def extract_prediction(row):
    raw = row['json_prediction']
    raw = raw.replace('```','')
    raw = raw.replace('json','')
    raw = '{' + raw.split('{')[1]
    raw = raw.split('}')[0] + '}'
    raw = raw.strip()
    print('raw is', raw)
    raw_dict = json.loads(raw)
    return str(raw_dict['answer'])

# %%
def is_correct(row):
    clean_prediction = row['predicted'].strip().lower()
    clean_correct = row['correct'].replace('Ayah','').strip().lower()
    return clean_correct == clean_prediction

# %%
def answer_question(model, question): 
    print(f'Answering question: {question["question"]}')
    options = [o.strip() for o in question['options'].split(',')]
    prompt = q_temp.render(question=question['question'], options = options)
    response = litellm.completion(
        model = model,
        messages = [ {
                        'role': 'system', 
                        'content': 'You are a helpful assistant.'
                    },
                     {'role' : 'user', 
                      'content' : prompt 
                      } ],
        timeout = 30.0,
        temperature = 0.0,  
        metadata = {'generation-name': 'ansari'},  
        #response_format= { "type" : "json_object" }, 
        num_retries = 5                  
    )
    result = response.choices[0].message
    print(f'Answer: {result}')
    return result

# %%
df['prediction'] = df.apply(lambda x: answer_question(MODEL, x), axis=1)
# Out:
# Answering question: Aşağıdaki harflerden hangisi izhar harflerinden biri değildir?
# Answer: Message(content='{\n  "answer": "kaf"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Şeddeli bir harften sonra gelen med harfi kaç hareke uzatılır?
# Answer: Message(content='{\n  "answer": 6\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdaki harflerden hangisi kalkale harflerinden biri değildir?
# Answer: Message(content='{\n  "answer": "cim"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdaki harflerden hangisi nun harfinden sonra gelen idğam harflerinden biri değildir?
# Answer: Message(content='{\n  "answer": "fe"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Erkeklerin altın takması İslam'da ne durumdadır?
# Answer: Message(content='{\n  "answer": "Haram"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Erkeklerin ipek giymesi İslam'da ne durumdadır?
# Answer: Message(content='{\n  "answer": "Haram"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Eşcinsel eylemler İslam'da ne durumdadır?
# Answer: Message(content='```json\n{\n  "answer": "Haram"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Evlilik öncesi cinsel ilişki İslam'da ne durumdadır?
# Answer: Message(content='```json\n{\n  "answer": "Haram"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Altın ve gümüş değişiminde anında olmayan işlemler İslam'da ne durumdadır?
# Answer: Message(content='{\n  "answer": "Haram"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi mezhep diğerlerine göre ikindi namazının başlamasını geciktirir?
# Answer: Message(content='{\n  "answer": "Hanefi"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İblis veya Şeytan hangi tür yaratılışa aittir?
# Answer: Message(content='{\n  "answer": "Cin"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed hangi yılda doğdu?
# Answer: Message(content='```json\n{\n  "answer": "MS 570"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed'in doğduğu yıla verilen isim nedir?
# Answer: Message(content='```json\n{\n  "answer": "Fil Yılı"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed'in ilk eşinin adı nedir?
# Answer: Message(content='{\n  "answer": "Hatice"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi namaz tek sayıda rekat içerir?
# Answer: Message(content='{\n  "answer": "Akşam"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Anne babası ve eşi olmayan, ama 2 oğlu ve 3 kızı olan bir adam ölür. Vasiyetinde 70.000 dolarlık mal varlığı vardır. Her kız ne kadar alır?
# Answer: Message(content='```json\n{\n  "answer": "10000 dolar"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdakilerden hangisi Tahavi akidesinin bir parçası değildir?
# Answer: Message(content='{\n  "answer": "Kader Tevhidi"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdakilerden hangisi Ayet-el Kürsi'dir?
# Answer: Message(content='{\n  "answer": "2:255"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: 29. cüzde kaç sure vardır?
# Answer: Message(content='```json\n{\n  "answer": "11"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Standartlaştırılmış Kur'an versiyonunda kaç ayet vardır?
# Answer: Message(content='{\n  "answer": "6236"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdaki aylardan hangisi Haram aylardan biri değildir?
# Answer: Message(content='{\n  "answer": "Safer"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kur'an'ın en uzun ayeti nedir?
# Answer: Message(content='{\n  "answer": "2:282"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Borç Ayeti olarak bilinen ayet nedir?
# Answer: Message(content='```json\n{\n  "answer": "2:282"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kaç peygamber Kur'an'da zikredilmiştir?
# Answer: Message(content='{\n  "answer": "25"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Yusuf'un Kur'an'a göre büyük dedesi kimdir?
# Answer: Message(content='```json\n{\n  "answer": "İbrahim"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: اتستبدلون kelimesinin üçlü kökü nedir?
# Answer: Message(content='{\n  "answer": "ba-da-la"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Peygamber Medine'yi yeniden adlandırmadan önce Medine hangi isimle biliniyordu?
# Answer: Message(content='```json\n{\n  "answer": "Yesrib"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed'in mensubu olduğu kabilenin adı neydi?
# Answer: Message(content='{\n  "answer": "Kureyş"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed zamanında Taif'te bulunan kabilenin adı neydi?
# Answer: Message(content='{\n  "answer": "Sakif"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İnançları nedeniyle öldürülen ilk kişinin adı neydi?
# Answer: Message(content='```json\n{\n  "answer": "Sümeyye bint Hayyat"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Kur'an'a göre cehennemi koruyan meleğin adı nedir?
# Answer: Message(content='{\n  "answer": "Malik"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Mekke'nin fethi hangi yılda gerçekleşti?
# Answer: Message(content='```json\n{\n  "answer": "8H"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Kur'an'da dört eşe kadar evliliğe izin veren ayet hangisidir?
# Answer: Message(content='{\n  "answer": "4:3"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Kur'an'da Musa ve Hızır'ın hikayesini anlatan sure hangisidir?
# Answer: Message(content='{\n  "answer": "Kehf"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İmam Nevevi'nin 40 hadisinin ilk hadisi neyi kapsar?
# Answer: Message(content='{\n  "answer": "Niyet"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Beni İsrail'in yeryüzünde iki kez fesat çıkaracağını belirten bir ayet var mı?
# Answer: Message(content='{\n  "answer": "17:4"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: ağaçlar kalem olsa ve yedi katı kadar daha olsa bile yetmeyeceğini anlatan ayet hangisidir?
# Answer: Message(content='{\n  "answer": "31:27"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kullu nafsin zaikatul mawt diyen ayet hangisidir?
# Answer: Message(content='{\n  "answer": "3:185"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Yusuf el-Karadavi hangi yıl vefat etti?
# Answer: Message(content='{\n  "answer": "2022"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Müslüman Kardeşler'in kurucusu kimdi?
# Answer: Message(content='{\n  "answer": "Hasan El Benna"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi halifelik en uzun süre hüküm sürdü?
# Answer: Message(content='```json\n{\n  "answer": "Osman"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi halifelik Mısır'ı halifeliğin merkezi yaptı?
# Answer: Message(content='{\n  "answer": "Fatımi"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Adı "merdiven" anlamına gelen surenin adı nedir?
# Answer: Message(content='{\n  "answer": "Mearic"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Muhammed (SAV) Ali (RA)'den rasulullah'ı sözleşmeden silmesini istediği anlaşma hangisiydi?
# Answer: Message(content='{\n  "answer": "Hudeybiye"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Peygamber bir sahabinin ölümünün intikamını almak için ağacın altında yemin etti. Bu sahabi kimdi?
# Answer: Message(content='```json\n{\n  "answer": "Osman"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kaç sure vardır?
# Answer: Message(content='{\n  "answer": "114"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Bu tefsirlerden hangisi en yenisidir?
# Answer: Message(content='{\n  "answer": "Sa\'di"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Dövme İslam'da yasak mı?
# Answer: Message(content='{\n  "answer": "Yasak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Pornografi İslam'da yasak mı?
# Answer: Message(content='{\n  "answer": "Yasak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İslam'da namazın durumu nedir?
# Answer: Message(content='{\n  "answer": "Farz"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İslam'da zekatın durumu nedir?
# Answer: Message(content='{\n  "answer": "Farz"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İslam'ın kumar konusundaki duruşu nedir?
# Answer: Message(content='```json\n{\n  "answer": "Yasak"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: İslam'ın alkol konusundaki duruşu nedir?
# Answer: Message(content='{\n  "answer": "Yasak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Öğle namazından önceki nafile namazların durumu nedir?
# Answer: Message(content='{\n  "answer": "Teşvik Edilen"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hadislerin en yüksek seviyesi hangisidir?
# Answer: Message(content='{\n  "answer": "Mütevatir"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Alimlerin peygamberlerin varisleri olduğunu anlatan hadiste, peygamberlerin geride ne bırakmadığı söylenir?
# Answer: Message(content='{\n  "answer": "dinar ve dirhem"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Madina'nın Yahudi kabilelerinden biri olmayan kabile hangisidir?
# Answer: Message(content='{\n  "answer": "Beni Kalun"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Haacer ve İsmail'e rastlayan kabilenin adı nedir?
# Answer: Message(content='{\n  "answer": "Curhum"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Alimlerin peygamberlerin varisleri olduğunu anlatan hadisi kim rivayet eder?
# Answer: Message(content='{\n  "answer": "Ebu Derda"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Peygamberin (SAV) annesi vefat ettikten hemen sonra ona kim baktı?
# Answer: Message(content='```json\n{\n  "answer": "Abdulmuttalib"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hz. Hatice'nin Peygamber (SAV) ile bazen görüşen kız kardeşinin adı nedir?
# Answer: Message(content='{\n  "answer": "Hala"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Selahaddin Haçlı Seferlerinde Avrupalıları hangi yılda yendi?
# Answer: Message(content='{\n  "answer": "1187 CE"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi İslam aliminin adı logaritmalara verilmiştir?
# Answer: Message(content='```json\n{\n  "answer": "El-Harezmi"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Peygamberin ölümünden sonra Kur'an'ı derlemekle görevlendirilen sahabi kimdi?
# Answer: Message(content='```json\n{\n  "answer": "Zeyd bin Sabit"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Adı Kur'an'da geçen tek sahabi kimdir?
# Answer: Message(content='{\n  "answer": "Zeyd bin Harise"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Allah İsra ve Mirac için Peygamberi (SAV) nasıl çağırır?
# Answer: Message(content='{\n  "answer": "Abd"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Ebu Bekir Kur'an'da geçiyor mu?
# Answer: Message(content='{\n  "answer": "dolaylı olarak thaani-ithnayn olarak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İki kuşaklı olarak bilinen kimdir?
# Answer: Message(content='{\n  "answer": "Esma bint Ebu Bekir"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangi Peygamberin (SAV) eşi Hudeybiye'de ona başını tıraş etmesini ve insanların onu takip edeceğini tavsiye etti?
# Answer: Message(content='```json\n{\n  "answer": "Ümmü Seleme"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Müslümanlar asli günaha inanır mı?
# Answer: Message(content='{\n  "answer": "Hayır Müslümanlar fıtrat kavramına inanır"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hangisi Nuh kavminin terk etmemeleri gerektiğini söylediği putlardan biridir?
# Answer: Message(content='{\n  "answer": "Vedd"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Nuh kavminin terk etmemeleri gerektiğini söylediği putları listeleyen Kur'an ayeti hangisidir?
# Answer: Message(content='{\n  "answer": "71:23"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Şu anda anlaşıldığı şekliyle İslam takviminin ilk ayı hangisidir?
# Answer: Message(content='{\n  "answer": "Muharrem"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Mevcut İslam Takvimi kimin döneminde oluşturuldu?
# Answer: Message(content='```json\n{\n  "answer": "Ömer"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Ey Allah'ım bana yolunda şehitlik nasip et ve ölümümü Resulünün şehrinde gerçekleşmesini sağla duasını yapan sahabi kimdir?
# Answer: Message(content='{\n  "answer": "Ömer"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Cebrail insan formunda Muhammed'e geldiğinde, hangi sahabiye benzerdi?
# Answer: Message(content='{\n  "answer": "Dihyah el-Kelbi"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Man aadaa lee waliyyan ile başlayan kudsi hadise göre, aşağıdakilerden hangisi Allah'ın evliyalarının özelliklerinden biri değildir?
# Answer: Message(content='```json\n{\n  "answer": "düşündüğü zihin"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdakilerden hangisi, Surah al-Waqi'ah'da kıyamet gününde bahsedilen 3 insan kategorisinden biri değildir?
# Answer: Message(content='{\n  "answer": "Ashaab al-Jaheem"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kur'an'ı bir Avrupa diline ilk kim çevirdi?
# Answer: Message(content='{\n  "answer": "Robert of Ketton"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: İslam'ın tüp bebek tedavisine bakışı nedir?
# Answer: Message(content='```json\n{\n  "answer": "sadece sperm kocadan ve yumurta eşten geliyorsa izin verilir"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Embriyonik gelişimin üç aşaması hakkındaki hadiste, bahsedilmeyen aşama hangisidir?
# Answer: Message(content='```json\n{\n  "answer": "ithaam (kemikler)"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdakilerden hangisi zekat almaya uygun 8 kategoriden biri değildir?
# Answer: Message(content='{\n  "answer": "cami inşaatı"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Aşağıdakilerden hangisi üç hac türünden biri değildir?
# Answer: Message(content='{\n  "answer": "matmum"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: En çok tercih edilen hac türü hangisidir?
# Answer: Message(content='{\n  "answer": "tamattu"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hadise göre, Cennetin kaç kapısı vardır?
# Answer: Message(content='{\n  "answer": 8\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Hadise göre, Raiyan kapısından girmek için ne gereklidir?
# Answer: Message(content='{\n  "answer": "oruç tutmak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kur'an'a göre, cehennemin kaç kapısı vardır?
# Answer: Message(content='```json\n{\n  "answer": 7\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question: Cehennemin kaç kapısı olduğunu söyleyen Kur'an ayeti hangisidir?
# Answer: Message(content='{\n  "answer": "15:44"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question: Kur'an'a göre cehennemin üzerinde kaç melek bekçi vardır?
# Answer: Message(content='```json\n{\n  "answer": "19"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Kur'an'ın hangi ayeti cehennemin üzerinde kaç melek bekçi olduğunu söyler?
# Answer: Message(content='{\n  "answer": "74:30"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Aşağıdakilerden hangisi Tahrim Suresi'nin sonunda bahsedilen kadınlardan biri değildir?
# Answer: Message(content='```json\n{\n  "answer": "İbrahim\'in karısı"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Hatice'nin kutsal kitaplar hakkında bilgili olan kuzeninin adı nedir?
# Answer: Message(content='```json\n{\n  "answer": "Varaka bin Nevfel"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  İslam'ın karşı cinsin kıyafetlerini giymek konusundaki duruşu nedir?
# Answer: Message(content='{\n  "answer": "Yasak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  İslam'ın canlı varlıkların heykelleri konusundaki duruşu nedir?
# Answer: Message(content='{\n  "answer": "Yasak"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Ana akım İslam'dan ayrılan ilk büyük grup kimlerdi?
# Answer: Message(content='{\n  "answer": "Hariciler"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Kötülüğü anlamada aşağıdakilerden hangisi Allah'ın iradesinin bir şekli değildir?
# Answer: Message(content='{\n  "answer": "İrade-i Nefsiyye"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  Adet gören kadınlar bayram namazına gitmeli mi?
# Answer: Message(content='{\n  "answer": "Evet ama namazın kendisine katılmazlar"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  "Ömer'i kim öldürdü?" sorusunun cevabı nedir?
# Answer: Message(content='```json\n{\n  "answer": "Ebu Lülua el-Mecusi"\n}\n```', role='assistant', tool_calls=None, function_call=None)
# Answering question:  "Laa yamassahu illal mutahharoon" diyen ayet hangisidir?
# Answer: Message(content='{\n  "answer": "56:79"\n}', role='assistant', tool_calls=None, function_call=None)
# Answering question:  "İnsanların yaptıkları nedeniyle yeryüzünde bozulma yayıldı" diyen ayet hangisidir?
# Answer: Message(content='```json\n{\n  "answer": "30:41"\n}\n```', role='assistant', tool_calls=None, function_call=None)

# %%
def extract_prediction(row):
    raw = row['prediction'].content
    raw = raw.replace('```','')
    raw = raw.replace('json','')
    raw = '{' + raw.split('{')[1]
    raw = raw.split('}')[0] + '}'
    raw = raw.strip()
    print('raw is', raw)
    raw_dict = json.loads(raw)
    return str(raw_dict['answer'])

# %%
df['predicted'] = df.apply(extract_prediction, axis=1)
# Out:
# raw is {
#   "answer": "kaf"
# }
# raw is {
#   "answer": 6
# }
# raw is {
#   "answer": "cim"
# }
# raw is {
#   "answer": "fe"
# }
# raw is {
#   "answer": "Haram"
# }
# raw is {
#   "answer": "Haram"
# }
# raw is {
#   "answer": "Haram"
# }
# raw is {
#   "answer": "Haram"
# }
# raw is {
#   "answer": "Haram"
# }
# raw is {
#   "answer": "Hanefi"
# }
# raw is {
#   "answer": "Cin"
# }
# raw is {
#   "answer": "MS 570"
# }
# raw is {
#   "answer": "Fil Yılı"
# }
# raw is {
#   "answer": "Hatice"
# }
# raw is {
#   "answer": "Akşam"
# }
# raw is {
#   "answer": "10000 dolar"
# }
# raw is {
#   "answer": "Kader Tevhidi"
# }
# raw is {
#   "answer": "2:255"
# }
# raw is {
#   "answer": "11"
# }
# raw is {
#   "answer": "6236"
# }
# raw is {
#   "answer": "Safer"
# }
# raw is {
#   "answer": "2:282"
# }
# raw is {
#   "answer": "2:282"
# }
# raw is {
#   "answer": "25"
# }
# raw is {
#   "answer": "İbrahim"
# }
# raw is {
#   "answer": "ba-da-la"
# }
# raw is {
#   "answer": "Yesrib"
# }
# raw is {
#   "answer": "Kureyş"
# }
# raw is {
#   "answer": "Sakif"
# }
# raw is {
#   "answer": "Sümeyye bint Hayyat"
# }
# raw is {
#   "answer": "Malik"
# }
# raw is {
#   "answer": "8H"
# }
# raw is {
#   "answer": "4:3"
# }
# raw is {
#   "answer": "Kehf"
# }
# raw is {
#   "answer": "Niyet"
# }
# raw is {
#   "answer": "17:4"
# }
# raw is {
#   "answer": "31:27"
# }
# raw is {
#   "answer": "3:185"
# }
# raw is {
#   "answer": "2022"
# }
# raw is {
#   "answer": "Hasan El Benna"
# }
# raw is {
#   "answer": "Osman"
# }
# raw is {
#   "answer": "Fatımi"
# }
# raw is {
#   "answer": "Mearic"
# }
# raw is {
#   "answer": "Hudeybiye"
# }
# raw is {
#   "answer": "Osman"
# }
# raw is {
#   "answer": "114"
# }
# raw is {
#   "answer": "Sa'di"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Farz"
# }
# raw is {
#   "answer": "Farz"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Teşvik Edilen"
# }
# raw is {
#   "answer": "Mütevatir"
# }
# raw is {
#   "answer": "dinar ve dirhem"
# }
# raw is {
#   "answer": "Beni Kalun"
# }
# raw is {
#   "answer": "Curhum"
# }
# raw is {
#   "answer": "Ebu Derda"
# }
# raw is {
#   "answer": "Abdulmuttalib"
# }
# raw is {
#   "answer": "Hala"
# }
# raw is {
#   "answer": "1187 CE"
# }
# raw is {
#   "answer": "El-Harezmi"
# }
# raw is {
#   "answer": "Zeyd bin Sabit"
# }
# raw is {
#   "answer": "Zeyd bin Harise"
# }
# raw is {
#   "answer": "Abd"
# }
# raw is {
#   "answer": "dolaylı olarak thaani-ithnayn olarak"
# }
# raw is {
#   "answer": "Esma bint Ebu Bekir"
# }
# raw is {
#   "answer": "Ümmü Seleme"
# }
# raw is {
#   "answer": "Hayır Müslümanlar fıtrat kavramına inanır"
# }
# raw is {
#   "answer": "Vedd"
# }
# raw is {
#   "answer": "71:23"
# }
# raw is {
#   "answer": "Muharrem"
# }
# raw is {
#   "answer": "Ömer"
# }
# raw is {
#   "answer": "Ömer"
# }
# raw is {
#   "answer": "Dihyah el-Kelbi"
# }
# raw is {
#   "answer": "düşündüğü zihin"
# }
# raw is {
#   "answer": "Ashaab al-Jaheem"
# }
# raw is {
#   "answer": "Robert of Ketton"
# }
# raw is {
#   "answer": "sadece sperm kocadan ve yumurta eşten geliyorsa izin verilir"
# }
# raw is {
#   "answer": "ithaam (kemikler)"
# }
# raw is {
#   "answer": "cami inşaatı"
# }
# raw is {
#   "answer": "matmum"
# }
# raw is {
#   "answer": "tamattu"
# }
# raw is {
#   "answer": 8
# }
# raw is {
#   "answer": "oruç tutmak"
# }
# raw is {
#   "answer": 7
# }
# raw is {
#   "answer": "15:44"
# }
# raw is {
#   "answer": "19"
# }
# raw is {
#   "answer": "74:30"
# }
# raw is {
#   "answer": "İbrahim'in karısı"
# }
# raw is {
#   "answer": "Varaka bin Nevfel"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Yasak"
# }
# raw is {
#   "answer": "Hariciler"
# }
# raw is {
#   "answer": "İrade-i Nefsiyye"
# }
# raw is {
#   "answer": "Evet ama namazın kendisine katılmazlar"
# }
# raw is {
#   "answer": "Ebu Lülua el-Mecusi"
# }
# raw is {
#   "answer": "56:79"
# }
# raw is {
#   "answer": "30:41"
# }

# %%
def is_correct(row):
    clean_prediction = row['predicted'].strip().lower()
    clean_correct = row['correct'].replace('Ayah','').strip().lower()
    return clean_correct == clean_prediction

# %%
df['correct_prediction'] = df.apply(is_correct, axis=1)

# %%
df['correct_prediction'].value_counts()
# Out:
# correct_prediction
# True     99
# False     1
# Name: count, dtype: int64

# %%
print(f'Model {MODEL} accuracy: {df["correct_prediction"].mean()}')
# Out:
# Model gpt-4o accuracy: 0.99

# %%
incorrect_answers = df[df['correct_prediction'] == False][['question', 'options', 'correct', 'predicted']]

# %%
incorrect_answers['question'].values
# Out:
# array(['Aşağıdaki harflerden hangisi kalkale harflerinden biri değildir?'],
#       dtype=object)
